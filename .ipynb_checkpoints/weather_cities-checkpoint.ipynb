# %%
#   dependencies and setup
import pandas as pd
from IPython.display import HTML

#   import the city data from WeatherPy into a dataframe
weather_cities_df = pd.read_csv('weather_cities.csv')
#   check the number of rows to verify contents - should be 570 rows
len(weather_cities_df)
# Out:
# 570

# %%
#   convert the dataframe to HTML and display it
weather_cities_html = weather_cities_df.to_html()
print(weather_cities_html)
#   checked that output contains 570 cities
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Max Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Windspeed</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>port alfred</td>
#       <td>ZA</td>
#       <td>72.64</td>
#       <td>92</td>
#       <td>51</td>
#       <td>14.72</td>
#       <td>-33.5906</td>
#       <td>26.8910</td>
#       <td>1641768476</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mar del plata</td>
#       <td>AR</td>
#       <td>78.01</td>
#       <td>36</td>
#       <td>0</td>
#       <td>8.99</td>
#       <td>-38.0023</td>
#       <td>-57.5575</td>
#       <td>1641768671</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>kwekwe</td>
#       <td>ZW</td>
#       <td>65.73</td>
# ...
